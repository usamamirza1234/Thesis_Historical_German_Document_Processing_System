# %%
# ===================================================================
# COMPLETE SMART OCR SYSTEM FOR GERMAN HISTORICAL DOCUMENTS
# ===================================================================

import os
import re
import cv2
import time
import json
import logging
import numpy as np
import pytesseract
from abc import ABC, abstractmethod
from datetime import datetime
from typing import Dict, List, Tuple, Optional, Any, Union
from dataclasses import dataclass, field
from enum import Enum
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
from pdf2image import convert_from_path
from PIL import Image

from config.settings import ProcessingConfig
from core.document_processor import SmartGermanDocumentProcessor
# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

def create_example_config() -> ProcessingConfig:
    """Create example configuration"""
    return ProcessingConfig(
        dpi=300,
        enable_debug=False,
        confidence_threshold=0.6,
        output_directory="output/smart_ocr_example",
        ocr_language='deu',
        enable_interactive_mode=True,
        save_intermediate_images=True,
        max_approaches_to_try=5
    )



"""Main example function"""
print("🚀 Smart German Document OCR System")
print("=" * 50)

# Create configuration
config = create_example_config()

# Initialize processor
processor = SmartGermanDocumentProcessor(config)

# Example document path
file_path = "pdfs/30s/30s/berufearchiv_5542.pdf"

try:
    print(f"🔄 Processing: {file_path}")

    # Process document
    metadata = processor.process_document(file_path, start_page=5, end_page=5)

    print(f"\n✅ Processing Results:")
    print(f"📅 Date: {metadata.date}")
    print(f"🏢 Publisher: {metadata.publisher}")
    print(f"📄 Document Type: {metadata.document_type}")
    print(f"⭐ Overall Confidence: {metadata.get_overall_confidence():.2f}")

    # Show processing details
    if metadata.processing_metadata.get('successful_approach'):
        print(f"🚀 Best OCR Approach: {metadata.processing_metadata['successful_approach']}")
        print(f"🎯 Final Confidence: {metadata.processing_metadata.get('final_confidence', 0):.2f}")

    if metadata.processing_metadata.get('analysis'):
        analysis_info = metadata.processing_metadata['analysis']
        print(f"📊 Document Type Detected: {analysis_info['document_type']}")
        print(f"🖼️  Image Quality: {analysis_info['image_quality']}")

    # Show text preview
    if metadata.raw_text_preview:
        print(f"\n📝 Text Preview (first 300 characters):")
        preview = metadata.raw_text_preview.replace('\n', ' ')
        print(f"   {preview}...")

    # Save results
    output_file = os.path.join(config.output_directory, "results.json")
    with open(output_file, 'w', encoding='utf-8') as f:
        f.write(metadata.to_json())

    print(f"\n💾 Results saved to: {output_file}")



except Exception as e:
    print(f"❌ Processing failed: {e}")
# Out:
# 2025-07-20 16:31:39,428 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-20 16:31:39,428 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-20 16:31:39,431 - smart_german_ocr - INFO - Processing document: pdfs/30s/30s/berufearchiv_5542.pdf
# 2025-07-20 16:31:39,431 - smart_german_ocr - INFO - Processing document: pdfs/30s/30s/berufearchiv_5542.pdf
# 🚀 Smart German Document OCR System
# ==================================================
# 🔄 Processing: pdfs/30s/30s/berufearchiv_5542.pdf
# 2025-07-20 16:31:40,402 - smart_german_ocr - INFO - Processing page 5
# 2025-07-20 16:31:40,402 - smart_german_ocr - INFO - Processing page 5
# 🔍 Smart Image Analysis Results:
# ==================================================
# 📄 Document Type: Fraktur
# ⭐ Detection Confidence: 0.60
# 🖼️  Image Quality: Good
# 💡 Brightness: 178/255
# 🌗 Contrast: 24.0
# 📏 Resolution: 1748x2418
# 📊 Text Density: 0.98
# 📏 Estimated Text Size: large
#
# 🧠 AI Analysis Reasoning:
#    1. Detected Fraktur script - using specialized preprocessing
#    2. Low contrast - using contrast enhancement
#
# 🚀 Recommended OCR Approaches (in priority order):
#    1. Enhanced
#    2. Fraktur Traditional
#    3. Fraktur Enhanced
#    4. Light
#    5. Standard
#
# ⚡ Your Options:
#    0. Use AI recommendation (auto-select best approach)
#    1-5. Choose specific approach
#    a. Try all recommended approaches
#    s. Skip analysis and use standard processing
# 2025-07-20 16:31:51,716 - ocr.ocr_engine - INFO - Image analysis: fraktur, quality: good
# 2025-07-20 16:34:06,875 - smart_german_ocr - INFO - Successfully extracted 1391 characters
# 2025-07-20 16:34:06,875 - smart_german_ocr - INFO - Successfully extracted 1391 characters
# 2025-07-20 16:34:06,877 - smart_german_ocr - INFO - Processing completed in 147.45s
# 2025-07-20 16:34:06,877 - smart_german_ocr - INFO - Processing completed in 147.45s
# ✅ Processing Results:
# 📅 Date: None
# 🏢 Publisher: None
# 📄 Document Type: None
# ⭐ Overall Confidence: 0.00
#
# 📝 Text Preview (first 300 characters):
#     --- Page 5 --- —  SET Mn u a N FEN an -. .. —. Pe -_  R\  UNURUN jo DU ı 7 u)  SS SOON  MINUMGT: N  HE ot —  UNUNUN 02 ad pe  MUND URE IRA DD DD m Doms no N  snhaltsuerzeichnig  I. Allgemeine Beltimmungen  Zuftändigfeit Eignungsbedingungen . I. Raffifihde und körperliche Anforderungen Il. Schulfenntniffe . IL Anforderungen für die Eignungsunterfuhungen Dura die Nrbeitsämter . . . IV, Lebensalter und Reichäangepörigteit . V. Nachweig der Eignung . oo. Lehrzeitdauer . . Lehrlingshöchftzahl . Anforderungen an den Eeprbetrieh Berwandtichaft rn  u. Berufsausbildung |  Grundforderungen . . Berufsausbildungsplan der Meifterlepre . Lehrplan der VBerufsihule . . WBerfftattwochenbudh .  Ill. Stoifchenpräfung  Allgemeines zur Zwifchenprüfung .  Praftiihe Prüfung .  Berfahren zur Abnahme der prattifchen Prüfung <heoretifche Prüfung .  IV. Gefellenprüfung  Allgemeines zur Gefellenprüfung .  rinbeftanforberungen Herrichten und Vorbereiten. von Rehrgeräten .  n Reinigen von Schornfteinen und Feuerun......
#
# 💾 Results saved to: output/smart_ocr_example\results.json
