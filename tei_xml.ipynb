# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_fachkraft_küche_2022.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:15:58,038 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:15:58,039 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_fachkraft_küche_2022.pdf
# 2025-07-26 18:15:58,636 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:16:03,229 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:16:07,585 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:16:12,774 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:16:16,984 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:16:20,982 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:16:25,180 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:16:33,682 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:16:37,436 - smart_german_ocr - INFO - Processing page 9
# 2025-07-26 18:16:40,765 - smart_german_ocr - INFO - Successfully extracted 28127 characters
# 2025-07-26 18:16:40,770 - smart_german_ocr - INFO - Processing completed in 42.73s
# Extracted date: 2022-03-09 00:00:00
# Extracted title: (Fachkraft-Küche-Ausbildungsverordnung - FKüAusbV)
# Extracted publisher: Bundesministerium für Wirtschaft und
# Extracted author: Bundesministerium für Wirtschaft und
# Extracted document_type:
# Verordnung
# Extracted year: 2022

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_geoinformationstechnologie_2010.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:16:40,781 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:16:40,782 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_geoinformationstechnologie_2010.pdf
# 2025-07-26 18:16:41,939 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:16:46,024 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:16:50,746 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:16:55,406 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:17:00,404 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:17:05,408 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:17:10,791 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:17:14,214 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:17:17,627 - smart_german_ocr - INFO - Processing page 9
# 2025-07-26 18:17:21,123 - smart_german_ocr - INFO - Processing page 10
# 2025-07-26 18:17:24,476 - smart_german_ocr - INFO - Processing page 11
# 2025-07-26 18:17:27,921 - smart_german_ocr - INFO - Processing page 12
# 2025-07-26 18:17:31,705 - smart_german_ocr - INFO - Processing page 13
# 2025-07-26 18:17:35,759 - smart_german_ocr - INFO - Processing page 14
# 2025-07-26 18:17:39,239 - smart_german_ocr - INFO - Processing page 15
# 2025-07-26 18:17:43,044 - smart_german_ocr - INFO - Processing page 16
# 2025-07-26 18:17:46,786 - smart_german_ocr - INFO - Processing page 17
# 2025-07-26 18:17:50,220 - smart_german_ocr - INFO - Processing page 18
# 2025-07-26 18:17:53,966 - smart_german_ocr - INFO - Processing page 19
# 2025-07-26 18:17:58,903 - smart_german_ocr - INFO - Successfully extracted 55777 characters
# 2025-07-26 18:17:58,911 - smart_german_ocr - INFO - Processing completed in 78.13s
# Extracted date: 2010-05-30 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung in der Geoinformationstechnologie*
# Extracted publisher: Bundesministerium für Wirtschaft
# Extracted author: Bundesministerium für Wirtschaft
# Extracted document_type:
# Verordnung
# Extracted year: 2010

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_holzbearbeitungsmechaniker_1980.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:17:58,925 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:17:58,926 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_holzbearbeitungsmechaniker_1980.pdf
# 2025-07-26 18:18:01,872 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:18:05,977 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:18:11,088 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:18:15,436 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:18:19,036 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:18:22,354 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:18:26,072 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:18:29,560 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:18:33,397 - smart_german_ocr - INFO - Processing page 9
# 2025-07-26 18:18:36,844 - smart_german_ocr - INFO - Processing page 10
# 2025-07-26 18:18:40,384 - smart_german_ocr - INFO - Processing page 11
# 2025-07-26 18:18:44,024 - smart_german_ocr - INFO - Processing page 12
# 2025-07-26 18:18:47,794 - smart_german_ocr - INFO - Successfully extracted 30039 characters
# 2025-07-26 18:18:47,799 - smart_german_ocr - INFO - Processing completed in 48.87s
# Extracted date: 1980-08-19 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung zum Holzbearbeitungsmechaniker/zur Holzbearbeitungsmechanikerin *
# Extracted publisher: None
# Extracted author: None
# Extracted document_type: Prüfungsanforderungen
# Extracted year: 1980

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_kartographen_1975.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:18:47,807 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:18:47,808 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_kartographen_1975.pdf
# 2025-07-26 18:18:50,215 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:18:54,190 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:18:59,501 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:19:06,075 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:19:13,008 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:19:20,572 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:19:27,890 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:19:34,975 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:19:42,835 - smart_german_ocr - INFO - Processing page 9
# 2025-07-26 18:19:46,061 - smart_german_ocr - INFO - Processing page 10
# 2025-07-26 18:19:52,085 - smart_german_ocr - INFO - Successfully extracted 21828 characters
# 2025-07-26 18:19:52,090 - smart_german_ocr - INFO - Processing completed in 64.28s
# Extracted date: 1975-02-25 00:00:00
# Extracted title: None
# Extracted publisher: None
# Extracted author: None
# Extracted document_type:
# Verordnung
# Extracted year: 1975

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_kartographen_1982.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:19:52,110 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:19:52,111 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_kartographen_1982.pdf
# 2025-07-26 18:19:54,130 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:19:58,760 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:20:04,000 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:20:08,413 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:20:11,924 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:20:15,677 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:20:22,383 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:20:25,567 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:20:28,283 - smart_german_ocr - INFO - Successfully extracted 19007 characters
# 2025-07-26 18:20:28,287 - smart_german_ocr - INFO - Processing completed in 36.18s
# Extracted date: 1982-03-17 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung zum Kartographen/zur Kartographin
# Extracted publisher: None
# Extracted author: None
# Extracted document_type:
# Verordnung
# Extracted year: 1982

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_kartographen_1997.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:20:28,294 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:20:28,295 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_kartographen_1997.pdf
# 2025-07-26 18:20:29,637 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:20:33,658 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:20:38,763 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:20:41,127 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:20:45,530 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:20:49,336 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:20:52,550 - smart_german_ocr - INFO - Successfully extracted 17062 characters
# 2025-07-26 18:20:52,553 - smart_german_ocr - INFO - Processing completed in 24.26s
# Extracted date: 1997-03-04 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung zum Kartographen/zur Kartographin*
# Extracted publisher: Bundesministerium für Wirtschaft und das Bundesmini-
# Extracted author: Bundesministerium für Wirtschaft und das Bundesmini-
# Extracted document_type:
# Verordnung
# Extracted year: 1997

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_sattler_1984.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:20:52,563 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:20:52,563 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_sattler_1984.pdf
# 2025-07-26 18:20:54,522 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:20:58,638 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:21:04,060 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:21:07,754 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:21:11,484 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:21:14,537 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:21:17,464 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:21:20,579 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:21:24,417 - smart_german_ocr - INFO - Successfully extracted 17062 characters
# 2025-07-26 18:21:24,420 - smart_german_ocr - INFO - Processing completed in 31.86s
# Extracted date: 1983-12-29 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung zum Sattler/zur Sattlerin
# Extracted publisher: None
# Extracted author: None
# Extracted document_type:
# Verordnung
# Extracted year: 1983

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_vermessungstechniker_1976.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:21:24,433 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:21:24,434 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_vermessungstechniker_1976.pdf
# 2025-07-26 18:21:27,303 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:21:31,863 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:21:37,585 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:21:42,483 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:21:48,032 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:21:51,008 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:21:53,987 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:21:56,784 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:22:03,955 - smart_german_ocr - INFO - Processing page 9
# 2025-07-26 18:22:10,327 - smart_german_ocr - INFO - Processing page 10
# 2025-07-26 18:22:17,485 - smart_german_ocr - INFO - Processing page 11
# 2025-07-26 18:22:24,413 - smart_german_ocr - INFO - Processing page 12
# 2025-07-26 18:22:29,272 - smart_german_ocr - INFO - Successfully extracted 23510 characters
# 2025-07-26 18:22:29,276 - smart_german_ocr - INFO - Processing completed in 64.84s
# Extracted date: 1976-11-29 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung zum Vermessungstechniker
# Extracted publisher: None
# Extracted author: None
# Extracted document_type:
# Verordnung
# Extracted year: 1976

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/tei_xml_examples/brd_vermessungstechniker_1994.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-26 18:22:29,294 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-26 18:22:29,294 - smart_german_ocr - INFO - Processing document: pdfs/tei_xml_examples/brd_vermessungstechniker_1994.pdf
# 2025-07-26 18:22:31,100 - smart_german_ocr - INFO - Processing page 1
# 2025-07-26 18:22:35,541 - smart_german_ocr - INFO - Processing page 2
# 2025-07-26 18:22:40,656 - smart_german_ocr - INFO - Processing page 3
# 2025-07-26 18:22:44,313 - smart_german_ocr - INFO - Processing page 4
# 2025-07-26 18:22:47,866 - smart_german_ocr - INFO - Processing page 5
# 2025-07-26 18:22:51,523 - smart_german_ocr - INFO - Processing page 6
# 2025-07-26 18:22:55,123 - smart_german_ocr - INFO - Processing page 7
# 2025-07-26 18:22:58,412 - smart_german_ocr - INFO - Processing page 8
# 2025-07-26 18:23:01,058 - smart_german_ocr - INFO - Successfully extracted 19658 characters
# 2025-07-26 18:23:01,062 - smart_german_ocr - INFO - Processing completed in 31.77s
# Extracted date: 1994-12-17 00:00:00
# Extracted title: Verordnung
# über die Berufsausbildung
# zum Vermessungstechniker/zur Vermessungstechnikerin‘
# Extracted publisher: Bundesministerium für Bildung, Wissenschaft, Forschung
# Extracted author: Bundesministerium für Bildung, Wissenschaft, Forschung
# Extracted document_type:
# Verordnung
# Extracted year: 1994

# %%
from core.document_processor import SmartGermanDocumentProcessor
from config.settings import ProcessingConfig

# config = ProcessingConfig(output_directory="output/simple")
config = ProcessingConfig.for_quick_processing("output/batch")
processor = SmartGermanDocumentProcessor(config)
metadata = processor.process_document("pdfs/new_data/berufearchiv_4.pdf")
print(f"Extracted date: {metadata.date}")
print(f"Extracted title: {metadata.title}")
print(f"Extracted publisher: {metadata.publisher}")
print(f"Extracted author: {metadata.author}")
print(f"Extracted document_type: {metadata.document_type}")
print(f"Extracted year: {metadata.year}")
# Out:
# 2025-07-27 09:56:28,599 - smart_german_ocr - INFO - Smart German Document Processor initialized
# 2025-07-27 09:56:28,600 - smart_german_ocr - INFO - Processing document: pdfs/new_data/berufearchiv_4.pdf
# 2025-07-27 09:56:31,896 - smart_german_ocr - INFO - Processing page 1
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:56:37,179 - smart_german_ocr - INFO - Processing page 2
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:56:53,264 - smart_german_ocr - INFO - Processing page 3
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:56:59,511 - smart_german_ocr - INFO - Processing page 4
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:57:05,748 - smart_german_ocr - INFO - Processing page 5
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:57:12,262 - smart_german_ocr - INFO - Processing page 6
# OCR failed: (1, 'Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/deu_frak.traineddata Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory. Failed loading language \'deu_frak\' Tesseract couldn\'t load any languages! Could not initialize tesseract.')
# 2025-07-27 09:57:17,711 - smart_german_ocr - INFO - Processing page 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 7
#       5 config = ProcessingConfig.for_quick_processing("output/batch")
#       6 processor = SmartGermanDocumentProcessor(config)
# ----> 7 metadata = processor.process_document("pdfs/new_data/berufearchiv_4.pdf")
#       8 print(f"Extracted date: {metadata.date}")
#       9 print(f"Extracted title: {metadata.title}")
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/core/document_processor.py:69, in SmartGermanDocumentProcessor.process_document(self, file_path, start_page, end_page, user_approach)
#      66     raise FileNotFoundError(f"File not found: {file_path}")
#      68 # Extract text
# ---> 69 text, processing_info = self._extract_text_from_document(
#      70     file_path, start_page, end_page, user_approach
#      71 )
#      73 if not text.strip():
#      74     raise ValueError("No text could be extracted from document")
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/core/document_processor.py:115, in SmartGermanDocumentProcessor._extract_text_from_document(self, file_path, start_page, end_page, user_approach)
#     112 file_ext = Path(file_path).suffix.lower()
#     114 if file_ext == '.pdf':
# --> 115     return self._extract_from_pdf(file_path, start_page, end_page, user_approach)
#     116 else:
#     117     return self._extract_from_image(file_path, user_approach)
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/core/document_processor.py:157, in SmartGermanDocumentProcessor._extract_from_pdf(self, pdf_path, start_page, end_page, user_approach)
#     153 page.save(temp_image_path)
#     155 try:
#     156     # Extract text from page
# --> 157     page_text, page_info = self._extract_from_image(
#     158         temp_image_path, user_approach
#     159     )
#     161     if page_text.strip():
#     162         all_text.append(f"\n--- Page {page_num} ---\n{page_text}")
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/core/document_processor.py:198, in SmartGermanDocumentProcessor._extract_from_image(self, image_path, user_approach)
#     195     user_choice = user_approach
#     197 # Extract text using smart engine
# --> 198 text, attempts, analysis = self.ocr_engine.extract_text_smart(
#     199     image_path, user_choice
#     200 )
#     202 # Prepare processing info
#     203 processing_info = {
#     204     'analysis': {
#     205         'document_type': analysis.document_type.value,
#    (...)
#     217     'final_confidence': 0.0
#     218 }
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/ocr/ocr_engine.py:73, in SmartOCREngine.extract_text_smart(self, image_path, user_choice)
#      70 if approach_name in self.config.excluded_approaches:
#      71     continue
# ---> 73 attempt = self._try_approach(image_path, approach_name, analysis)
#      74 attempts.append(attempt)
#      76 if attempt.success and attempt.confidence > best_result["confidence"]:
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/ocr/ocr_engine.py:137, in SmartOCREngine._try_approach(self, image_path, approach_name, analysis)
#     134     cv2.imwrite(processed_path, processed_image)
#     136 # Perform OCR
# --> 137 text = self._perform_ocr(processed_path)
#     139 # Clean up temporary file
#     140 if not self.config.save_intermediate_images and os.path.exists(processed_path):
#
# File ~/Downloads/RG/Thesis_Historical_German_Document_Processing_System/ocr/ocr_engine.py:173, in SmartOCREngine._perform_ocr(self, image_path)
#     170 """Perform OCR on processed image"""
#     171 try:
#     172     # Try primary language
# --> 173     text = pytesseract.image_to_string(
#     174         image_path,
#     175         lang=self.config.ocr_language,
#     176         config=self.config.tesseract_config
#     177     )
#     179     # If result is poor, try fallback languages
#     180     if len(text.strip()) < 20:
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/site-packages/pytesseract/pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/site-packages/pytesseract/pytesseract.py:489, in image_to_string.<locals>.<lambda>()
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
#     486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/site-packages/pytesseract/pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)
#     349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/site-packages/pytesseract/pytesseract.py:282, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     279     else:
#     280         raise TesseractNotFoundError()
# --> 282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#     284         raise TesseractError(proc.returncode, get_errors(error_string))
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/site-packages/pytesseract/pytesseract.py:144, in timeout_manager(proc, seconds)
#     142 try:
#     143     if not seconds:
# --> 144         yield proc.communicate()[1]
#     145         return
#     147     try:
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/subprocess.py:1154, in Popen.communicate(self, input, timeout)
#    1151     endtime = None
#    1153 try:
# -> 1154     stdout, stderr = self._communicate(input, endtime, timeout)
#    1155 except KeyboardInterrupt:
#    1156     # https://bugs.python.org/issue25942
#    1157     # See the detailed comment in .wait().
#    1158     if timeout is not None:
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/subprocess.py:2021, in Popen._communicate(self, input, endtime, orig_timeout)
#    2014     self._check_timeout(endtime, orig_timeout,
#    2015                         stdout, stderr,
#    2016                         skip_check_and_raise=True)
#    2017     raise RuntimeError(  # Impossible :)
#    2018         '_check_timeout(..., skip_check_and_raise=True) '
#    2019         'failed to raise TimeoutExpired.')
# -> 2021 ready = selector.select(timeout)
#    2022 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2024 # XXX Rewrite these to use non-blocking I/O on the file
#    2025 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/envs/thesis_document_processor/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
